# %%
# import package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# model Linear Regression
from sklearn.linear_model import LinearRegression
# code tambahan untuk membuat model Polynomial Regression. dengan code nya Linear Regression + ini = Polynomial Regrsssion
from sklearn.preprocessing import PolynomialFeatures

# untuk pisahin data jadi training dan testing data
from sklearn.model_selection import train_test_split

# %%
df_bos = pd.read_csv("https://raw.githubusercontent.com/stefkwan-h8/dataset/main/boston.csv")
df_bos
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
# merapikan data

# pilih fitur yang mau digunakan
# contoh kali ini, misal kita mau buat model yang bisa prediksi harga rumah dari jumlah kamarnya (kolom RM)
x = df_bos[["RM"]]
y = df_bos["MEDV"]

display(x.head(), y[:5])
# Out:
#       RM
# 0  6.575
# 1  6.421
# 2  7.185
# 3  6.998
# 4  7.147
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
# cek missing values
df_bos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
# sedikit eksplorasi data
df_bos.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# pisahin data jadi training dan testing data
x_train, x_test, y_train, y_test = train_test_split(x, y)

print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (379, 1) (127, 1)
# (379,) (127,)

# %%
# buat dan latih model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.5439955445230953

# %%
# kalau ada 2 kamar, harga rumah berapa?
model.predict([[2]])
# Out:
# c:\Users\razan\anaconda3\envs\myenv\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-14.53134394])

# %%
# optional - visualisasi, karena cuma ada 1 fitur
plt.scatter(x=x, y=y)
plt.xlabel("jumlah kamar")
plt.ylabel("harga rumah")
plt.title("data harga rumah Boston")

y_pred = model.predict(x)
plt.plot(x, y_pred, color="orange")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\razan\anaconda3\envs\myenv\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\razan\anaconda3\envs\myenv\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\razan\anaconda3\envs\myenv\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), None)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# c:\Users\razan\Documents\VS\sesi 7\Untitled-1.ipynb Cell 11 in <cell line: 8>()
# ...

# %%
print(np.array(x))
# Out:
# [[6.575]
#  [6.421]
#  [7.185]
#  [6.998]
#  [7.147]
#  [6.43 ]
#  [6.012]
#  [6.172]
#  [5.631]
#  [6.004]
#  [6.377]
#  [6.009]
#  [5.889]
#  [5.949]
#  [6.096]
#  [5.834]
#  [5.935]
#  [5.99 ]
#  [5.456]
#  [5.727]
#  [5.57 ]
#  [5.965]
#  [6.142]
#  [5.813]
#  [5.924]
#  [5.599]
#  [5.813]
#  [6.047]
#  [6.495]
#  [6.674]
#  [5.713]
#  [6.072]
#  [5.95 ]
#  [5.701]
#  [6.096]
#  [5.933]
#  [5.841]
#  [5.85 ]
#  [5.966]
#  [6.595]
#  [7.024]
#  [6.77 ]
#  [6.169]
#  [6.211]
#  [6.069]
#  [5.682]
#  [5.786]
#  [6.03 ]
#  [5.399]
#  [5.602]
#  [5.963]
#  [6.115]
#  [6.511]
#  [5.998]
#  [5.888]
#  [7.249]
#  [6.383]
#  [6.816]
#  [6.145]
#  [5.927]
#  [5.741]
#  [5.966]
#  [6.456]
#  [6.762]
#  [7.104]
#  [6.29 ]
#  [5.787]
#  [5.878]
#  [5.594]
#  [5.885]
#  [6.417]
#  [5.961]
#  [6.065]
#  [6.245]
#  [6.273]
#  [6.286]
#  [6.279]
#  [6.14 ]
#  [6.232]
#  [5.874]
#  [6.727]
#  [6.619]
#  [6.302]
#  [6.167]
#  [6.389]
#  [6.63 ]
#  [6.015]
#  [6.121]
#  [7.007]
#  [7.079]
# ...

# %%
# optional - visualisasi, karena cuma ada 1 fitur
plt.scatter(x=x, y=y)
plt.xlabel("jumlah kamar")
plt.ylabel("harga rumah")
plt.title("data harga rumah Boston")

y_pred = model.predict(x)
plt.plot(np.array(x), y_pred, color="orange")
plt.show()
