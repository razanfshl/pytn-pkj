# %%
import numpy as np
import pandas as pd

# %%
df_nba = pd.read_csv("https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv")

# %%
df_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df = pd.DataFrame(data= [
                        [2, 5, 6, 7, 4],
                        [3, 4, 2, 1, 4],
                        [2, 3, 4, 6, 2]])
df.columns= ["senin", "selasa", "rabu", "kamis", "jumat"]
df.index = ["coklat", "srikaya", "manis"]
df
# Out:
#          senin  selasa  rabu  kamis  jumat
# coklat       2       5     6      7      4
# srikaya      3       4     2      1      4
# manis        2       3     4      6      2

# %%
df
# Out:
#          senin  selasa  rabu  kamis  jumat
# coklat       2       5     6      7      4
# srikaya      3       4     2      1      4
# manis        2       3     4      6      2

# %%
df_excel = pd.read_excel (r"C:\Users\razan\Documents\VS\Book1.xlsx", index_col=0) 
df_excel
# Out:
#       Warna Daun Apikal  Bulu Halus Apikal  Bentuk Daun  Warna Daun  \
# KLON
# A1                    2                  9            2           2
# A2                    1                  1            3           2
# A3                    2                  9            1           2
# A4                    1                  9            2           2
# A5                    3                  9            1           2
# A6                    1                  9            2           2
# A7                    4                  1            2           3
# A8                    1                  9            2           2
# A9                    1                  9            3           2
# A10                   1                  9            3           2
# A11                   2                  9            2           2
# A12                   3                  9            3           2
#
#       Variegation  Warna Vena  Petiola  Warna Petiola  Bentuk Stipule  \
# ...

# %%
df
# Out:
#          senin  selasa  rabu  kamis  jumat
# coklat       2       5     6      7      4
# srikaya      3       4     2      1      4
# manis        2       3     4      6      2

# %%
df_excel[["Variegation", "Bentuk Daun"]]
# Out:
#      Variegation  Bentuk Daun
# A1             9            2
# A2             1            3
# A3             9            1
# A4             9            2
# A5             9            1
# A6             9            2
# A7             9            2
# A8             9            2
# A9             9            3
# A10            9            3
# A11            9            2
# A12            9            3

# %%
df
# Out:
#          senin  selasa  rabu  kamis  jumat
# coklat       2       5     6      7      4
# srikaya      3       4     2      1      4
# manis        2       3     4      6      2

# %%
kondisi = (df >3)
df[kondisi]
# Out:
#          senin  selasa  rabu  kamis  jumat
# coklat     NaN     5.0   6.0    7.0    4.0
# srikaya    NaN     4.0   NaN    NaN    4.0
# manis      NaN     NaN   4.0    6.0    NaN

# %%
df
# Out:
#          senin  selasa  rabu  kamis  jumat
# coklat       2       5     6      7      4
# srikaya      3       4     2      1      4
# manis        2       3     4      6      2

# %%
df_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
kondisi_th = (df_nba["year_id"] == 2010)
df_nba[kondisi_th][["pts"]]
# Out:
#         pts
# 111032   95
# 111033   89
# 111034  102
# 111035   91
# 111036   92
# ...     ...
# 113651   92
# 113652   67
# 113653   89
# 113654   83
# 113655   79
#
# [2624 rows x 1 columns]

# %%
kondisi_nyk = (df_nba["team_id"] == "NYK")
df_nba[kondisi_nyk]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 1               1  194611010TRH   NBA        1     1947   11/1/1946
# 3               2  194611020CHS   NBA        1     1947   11/2/1946
# 23             12  194611070STB   NBA        1     1947   11/7/1946
# 37             19  194611110NYK   NBA        0     1947  11/11/1946
# 54             28  194611160NYK   NBA        0     1947  11/16/1946
# ...           ...           ...   ...      ...      ...         ...
# 126025      63013  201504080NYK   NBA        0     2015    4/8/2015
# 126056      63029  201504100NYK   NBA        0     2015   4/10/2015
# 126072      63037  201504110ORL   NBA        1     2015   4/11/2015
# 126094      63048  201504130ATL   NBA        1     2015   4/13/2015
# 126147      63074  201504150NYK   NBA        0     2015   4/15/2015
#
#         seasongame  is_playoffs team_id fran_id  ...  win_equiv  opp_id  \
# 1                1            0     NYK  Knicks  ...  41.705170     TRH
# ...

# %%
df_nba[kondisi_th & kondisi_nyk]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 111053      55527  200910280MIA   NBA        1     2010  10/28/2009
# 111072      55537  200910300CHA   NBA        1     2010  10/30/2009
# 111103      55552  200910310NYK   NBA        0     2010  10/31/2009
# 111126      55564  200911020NYK   NBA        0     2010   11/2/2009
# 111160      55581  200911040NYK   NBA        0     2010   11/4/2009
# ...           ...           ...   ...      ...      ...         ...
# 113352      56677  201004070IND   NBA        1     2010    4/7/2010
# 113396      56699  201004090ORL   NBA        1     2010    4/9/2010
# 113428      56715  201004110NYK   NBA        0     2010   4/11/2010
# 113447      56724  201004120NYK   NBA        0     2010   4/12/2010
# 113486      56744  201004140TOR   NBA        1     2010   4/14/2010
#
#         seasongame  is_playoffs team_id fran_id  ...  win_equiv  opp_id  \
# 111053           1            0     NYK  Knicks  ...  32.153221     MIA
# ...

# %%
df_nba.rename(columns={"year_id" : "year", "date_game" : "date"})
# Out:
#         gameorder       game_id lg_id  _iscopy  year       date  seasongame  \
# 0               1  194611010TRH   NBA        0  1947  11/1/1946           1
# 1               1  194611010TRH   NBA        1  1947  11/1/1946           1
# 2               2  194611020CHS   NBA        0  1947  11/2/1946           1
# 3               2  194611020CHS   NBA        1  1947  11/2/1946           2
# 4               3  194611020DTF   NBA        0  1947  11/2/1946           1
# ...           ...           ...   ...      ...   ...        ...         ...
# 126309      63155  201506110CLE   NBA        0  2015  6/11/2015         100
# 126310      63156  201506140GSW   NBA        0  2015  6/14/2015         102
# 126311      63156  201506140GSW   NBA        1  2015  6/14/2015         101
# 126312      63157  201506170CLE   NBA        0  2015  6/16/2015         102
# 126313      63157  201506170CLE   NBA        1  2015  6/16/2015         103
#
# ...

# %%
df_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df_nba.head(7)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
#
#    is_playoffs team_id   fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH   Huskies  ...  40.294830     NYK        Knicks
# 1            0     NYK    Knicks  ...  41.705170     TRH       Huskies
# 2            0     CHS     Stags  ...  42.012257     NYK        Knicks
# 3            0     NYK    Knicks  ...  40.692783     CHS         Stags
# ...

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
kondisi_bos = (df_nba["team_id"] == "BOS")
df_nba[kondisi_bos][["pts"]].mean()
# Out:
# pts    104.466233
# dtype: float64

# %%
df_nba.groupby(["team_id"])["pts"].mean()
# Out:
# team_id
# ANA    111.589744
# AND     86.013889
# ATL    101.920198
# BAL    113.293303
# BLB     79.698073
#           ...
# WAS     96.551186
# WAT     79.370968
# WSA    118.395604
# WSB    104.214859
# WSC     76.931271
# Name: pts, Length: 104, dtype: float64

# %%
df_nba.groupby(["team_id"])["pts"].agg(["min","mean","max","sum","std"])
# Out:
#          min        mean  max     sum        std
# team_id
# ANA       85  111.589744  147    8704  12.913736
# AND       50   86.013889  123    6193  12.868230
# ATL       58  101.920198  155  411248  13.559654
# BAL       79  113.293303  156   98112  12.568954
# BLB       50   79.698073  126   37219  11.981784
# ...      ...         ...  ...     ...        ...
# WAS       63   96.551186  147  142413  12.052826
# WAT       59   79.370968  104    4921  10.479072
# WSA       91  118.395604  162   10774  13.850695
# WSB       69  104.214859  161  207596  11.993637
# WSC       38   76.931271  118   22387  11.562816
#
# [104 rows x 5 columns]

# %%
df.loc[["srikaya"],["selasa"]] = 5
df
# Out:
#          senin  selasa  rabu  kamis  jumat
# coklat       2       5     6      7      4
# srikaya      3       5     2      1      4
# manis        2       3     4      6      2

# %%
df["sabtu"] = [8,9,10]

# %%
df
# Out:
#          senin  selasa  rabu  kamis  jumat  sabtu
# coklat       2       5     6      7      4      8
# srikaya      3       5     2      1      4      9
# manis        2       3     4      6      2     10

# %%
df["total"] = df.sum(axis=1)
# Out:
#          senin  selasa  rabu  kamis  jumat  sabtu  total
# coklat       2       5     6      7      4      8     32
# srikaya      3       5     2      1      4      9     24
# manis        2       3     4      6      2     10     27

# %%
df
# Out:
#          senin  selasa  rabu  kamis  jumat  sabtu  total
# coklat       2       5     6      7      4      8     32
# srikaya      3       5     2      1      4      9     24
# manis        2       3     4      6      2     10     27

# %%
df.loc["tawar"] = np.arange(7)

# %%
df
# Out:
#          senin  selasa  rabu  kamis  jumat  sabtu  total
# coklat       2       5     6      7      4      8     32
# srikaya      3       5     2      1      4      9     24
# manis        2       3     4      6      2     10     27
# tawar        0       1     2      3      4      5      6

# %%
df2 = pd.DataFrame({"senin":[5], "selasa":[4]}, index=["pisang"])
df2
# Out:
#         senin  selasa
# pisang      5       4

# %%
df3 = pd.concat()

# %%
pd.Series(data= [5,6,7], index=["Amsterdam","Bali","Jakarta"])
# Out:
# Amsterdam    5
# Bali         6
# Jakarta      7
# dtype: int64

# %%
buah_jumlah = pd.Series({"apel": 5, "pisang": 2, "mangga":3})
buah_harga = pd.Series({"apel": 5500, "pisang":12000, "mangga":32000, "semangka":17500})

display(buah_jumlah)
display(buah_harga)
# Out:
# apel      5
# pisang    2
# mangga    3
# dtype: int64
# apel         5500
# pisang      12000
# mangga      32000
# semangka    17500
# dtype: int64

# %%
df_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df_nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df_nba["notes"]
